# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai import *
from fastai.text import *
from fastai.callbacks import CSVLogger, SaveModelCallback

import torch.backends.cudnn as cudnn

from train_search import DartsRnnSearch, ArchParamUpdate, PrintGenotype
from darts_callbacks import HidInit, Regu, SaveModel, ResumeModel, GcCol

# %%
# random seed for reproducibility.
seed = 135
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

gpu = 0
torch.cuda.set_device(gpu)
cudnn.benchmark = True
cudnn.enabled=True
torch.backends.cudnn.deterministic = True
torch.cuda.manual_seed_all(seed)

bptt = 35
bs_train, bs_val = 256, 64
dat = load_data('data', 'penn_db', bs=bs_train, bptt=bptt)
dat.valid_dl.batch_size = bs_val
search_dat = list(iter(load_data('data', 'penn_db', bs=bs_train, bptt = bptt).valid_dl))

arch_lr = 3e-3
arch_wdecay = 1e-3
vocab_sz = len(dat.train_ds.x.vocab.itos)
emb_sz = 300
hid_sz = 300
wdecay = 5e-7
dropout = 0.75
dropouth = 0.25
dropoutx = 0.75
dropouti = 0.2
dropoute = 0.
clip = 0.25

# %%
csv_name = 'train_search'
model_name = 'train_search'
# resume_model = 'train_search'

# %%
learn = Learner(dat, DartsRnnSearch(emb_sz = emb_sz, vocab_sz = vocab_sz,
                                    ninp = emb_sz, nhid = hid_sz, 
                                    dropout = dropout, dropouth = dropouth, dropoutx = dropoutx,
                                    dropouti = dropouti, dropoute = dropoute,
                                    bs_train = bs_train, bs_val = bs_val),
                opt_func = torch.optim.SGD,
                callback_fns = [
                    HidInit,
                    partial(ArchParamUpdate, search_dat=search_dat,
                            arch_lr=arch_lr, arch_wdecay=arch_wdecay, wdecay=wdecay),
                    Regu,
                    PrintGenotype,
                    partial(GradientClipping, clip=clip),
                    partial(CSVLogger, filename = csv_name, append = True),
                    GcCol,
#                     partial(ResumeModel, name = resume_model) 
                ], 
                wd = wdecay
                )

total_params = sum(x.nelement() for x in learn.model.parameters())
print('Total params:', total_params)
print(learn.model.genotype_parse())
# learn.data.valid_dl=None
# Out:
# Total params: 4810000
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('identity', 1), ('relu', 3), ('sigmoid', 4), ('sigmoid', 3), ('identity', 6), ('identity', 1)], concat=range(1, 9))

# %%
learn.fit(50, 20, callbacks=[
#     SaveModel(learn, gap = 1, name=model_name),
    SaveModelCallback(learn, name=model_name) # save on improvement
                           ])
# Out:
# Total time: 4:21:05 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.377739</td>
#       <td>8.914400</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>9.024400</td>
#       <td>7.874600</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.465348</td>
#       <td>7.455300</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.251266</td>
#       <td>7.209497</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.137778</td>
#       <td>7.105574</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8.029912</td>
#       <td>6.999118</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>7.972732</td>
#       <td>6.931962</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>7.771575</td>
#       <td>6.910496</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>7.630065</td>
#       <td>6.853231</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>7.517681</td>
#       <td>6.790563</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>7.386724</td>
#       <td>6.772378</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>7.236539</td>
#       <td>6.759993</td>
#       <td>05:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7.063982</td>
#       <td>6.703610</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6.905414</td>
#       <td>6.662308</td>
#       <td>05:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>6.708851</td>
#       <td>6.653984</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>6.539793</td>
#       <td>6.653328</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>6.402159</td>
#       <td>6.616840</td>
#       <td>05:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6.250990</td>
#       <td>6.605050</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6.140637</td>
#       <td>6.613458</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>6.026720</td>
#       <td>6.599876</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.945973</td>
#       <td>6.587843</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>5.857794</td>
#       <td>6.579211</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>5.771217</td>
#       <td>6.584734</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>5.714971</td>
#       <td>6.569280</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5.660535</td>
#       <td>6.567819</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>5.617890</td>
#       <td>6.582723</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>5.579669</td>
#       <td>6.570678</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>5.551519</td>
#       <td>6.581318</td>
#       <td>05:09</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>5.528355</td>
#       <td>6.565953</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>5.496869</td>
#       <td>6.573961</td>
#       <td>05:10</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>5.477722</td>
#       <td>6.563119</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>5.459666</td>
#       <td>6.568295</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>5.440758</td>
#       <td>6.562510</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>5.418176</td>
#       <td>6.566048</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>5.401654</td>
#       <td>6.563069</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>5.380398</td>
#       <td>6.576956</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>5.363576</td>
#       <td>6.564011</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>5.353090</td>
#       <td>6.572284</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>5.335605</td>
#       <td>6.563518</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>5.327987</td>
#       <td>6.566296</td>
#       <td>05:10</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>5.317882</td>
#       <td>6.569047</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>5.310230</td>
#       <td>6.571513</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>5.296213</td>
#       <td>6.565657</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>5.285232</td>
#       <td>6.565644</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>5.273549</td>
#       <td>6.572789</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>5.266336</td>
#       <td>6.559350</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>5.260991</td>
#       <td>6.564308</td>
#       <td>05:10</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>5.254736</td>
#       <td>6.575763</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>5.246768</td>
#       <td>6.559757</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>5.242108</td>
#       <td>6.566053</td>
#       <td>05:14</td>
#     </tr>
#   </tbody>
# </table>
# Genotype(recurrent=[('identity', 0), ('identity', 0), ('relu', 2), ('sigmoid', 2), ('sigmoid', 2), ('tanh', 2), ('relu', 2), ('relu', 5)], concat=range(1, 9))
# Better model found at epoch 0 with val_loss value: 8.914400100708008.
# Genotype(recurrent=[('relu', 0), ('tanh', 1), ('identity', 2), ('relu', 3), ('sigmoid', 0), ('tanh', 2), ('tanh', 5), ('relu', 4)], concat=range(1, 9))
# Better model found at epoch 1 with val_loss value: 7.874600410461426.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 0), ('sigmoid', 1), ('tanh', 2), ('identity', 5), ('relu', 4)], concat=range(1, 9))
# Better model found at epoch 2 with val_loss value: 7.455300331115723.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('tanh', 4), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 3 with val_loss value: 7.209496974945068.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('tanh', 4), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 4 with val_loss value: 7.105574131011963.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('identity', 5), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 5 with val_loss value: 6.999118328094482.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('tanh', 4), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 6 with val_loss value: 6.931961536407471.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('identity', 5), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 7 with val_loss value: 6.910495758056641.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 0), ('tanh', 2), ('identity', 5), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 8 with val_loss value: 6.853230953216553.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 0), ('tanh', 2), ('identity', 2), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 9 with val_loss value: 6.790562629699707.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('identity', 5), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 10 with val_loss value: 6.772377967834473.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('tanh', 2), ('tanh', 2), ('identity', 2), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 11 with val_loss value: 6.759993076324463.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('identity', 4), ('tanh', 2), ('identity', 2), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 12 with val_loss value: 6.703609943389893.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('identity', 0), ('tanh', 2), ('identity', 2), ('sigmoid', 2)], concat=range(1, 9))
# Better model found at epoch 13 with val_loss value: 6.6623077392578125.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('identity', 4), ('tanh', 2), ('identity', 2), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 14 with val_loss value: 6.653984069824219.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 2), ('identity', 4), ('tanh', 2), ('tanh', 5), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 15 with val_loss value: 6.653327941894531.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 4), ('tanh', 2), ('identity', 2), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 16 with val_loss value: 6.616840362548828.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 4), ('sigmoid', 0), ('identity', 2), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 17 with val_loss value: 6.605050086975098.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 1), ('identity', 4), ('identity', 2), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('tanh', 5), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 19 with val_loss value: 6.599876403808594.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('identity', 2), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 20 with val_loss value: 6.58784294128418.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('tanh', 5), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# Better model found at epoch 21 with val_loss value: 6.579211235046387.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Better model found at epoch 23 with val_loss value: 6.569279670715332.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('identity', 3), ('identity', 1)], concat=range(1, 9))
# Better model found at epoch 24 with val_loss value: 6.567819118499756.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Better model found at epoch 28 with val_loss value: 6.565952777862549.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('identity', 2), ('tanh', 5), ('identity', 4)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Better model found at epoch 30 with val_loss value: 6.563118934631348.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Better model found at epoch 32 with val_loss value: 6.562509536743164.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('identity', 1)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('sigmoid', 2)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('identity', 4)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('identity', 4)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('identity', 0), ('tanh', 5), ('identity', 4)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 0), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Better model found at epoch 45 with val_loss value: 6.55935001373291.
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
# Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('identity', 2), ('identity', 4), ('relu', 4), ('tanh', 5), ('relu', 5)], concat=range(1, 9))
